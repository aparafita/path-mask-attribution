# %%
import os.path

import torch
from torch import nn, optim

import numpy as np

% matplotlib inline
import matplotlib.pyplot as plt

from cifar10_cnn import *
from utils import *

# %%
DISABLE_CUDA = False

if not DISABLE_CUDA and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
dataset = CIFAR10(
    os.path.join(*'data/cifar-10-batches-py'.split('/')),
    batch_size=32, val_size=.2
)

# %%
def cifar10_model():
    feature_model = nn.Sequential( # 3, 32, 32
        OrderedDict([
            ('conv1', nn.Conv2d(3, 64, kernel_size=3, stride=1, bias=False)), # 64, 30, 30
            ('conv1_bn', nn.BatchNorm2d(64)),
            ('conv1_relu', nn.ReLU()),
            ('conv2', nn.Conv2d(64, 64, kernel_size=3, stride=1, bias=False)), # 64, 28, 28
            ('conv2_bn', nn.BatchNorm2d(64)),
            ('conv2_relu', nn.ReLU()),
            ('maxpool_1', nn.MaxPool2d(2)), # 64, 14, 14
            ('conv3', nn.Conv2d(64, 128, kernel_size=3, stride=1, bias=False)), # 128, 12, 12
            ('conv3_bn', nn.BatchNorm2d(128)),
            ('conv3_relu', nn.ReLU()),
            ('conv4', nn.Conv2d(128, 128, kernel_size=3, stride=1, bias=False)), # 128, 10, 10
            ('conv4_bn', nn.BatchNorm2d(128)),
            ('conv4_relu', nn.ReLU()),
            ('maxpool_2', nn.MaxPool2d(2)), # 128, 5, 5
            ('conv5', nn.Conv2d(128, 256, kernel_size=3, stride=1, bias=False)), # 256, 3, 3
            ('conv5_bn', nn.BatchNorm2d(256)),
            ('conv5_relu', nn.ReLU()),
        ])
    )

    classifier_model = nn.Sequential(
        OrderedDict([
            ('dense1', nn.Linear(256 * 3 * 3, 256, bias=False)),
            ('dense1_bn', nn.BatchNorm1d(256)),
            ('dense1_relu', nn.ReLU()),
            ('dense1_dropout', nn.Dropout()),
            ('dense2', nn.Linear(256, 128, bias=False)),
            ('dense2_bn', nn.BatchNorm1d(128)),
            ('dense2_relu', nn.ReLU()),
            ('dense2_dropout', nn.Dropout()),
            ('output', nn.Linear(128, 10)),
        ])
    )

    model = nn.Sequential(
        OrderedDict([
            ('features', feature_model),
            ('flatten', Flatten()),
            ('classifier', classifier_model)
        ])
    )
    
    return model

# %%
N_EPOCHS = 100

model = cifar10_model()
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, N_EPOCHS + 1):
    model.train()
    train_loss = 0
    train_accuracy = 0
    
    for X, y, label in dataset.train_loader:
        X = X.to(device); y = y.to(device)
        
        model.zero_grad()
        optimizer.zero_grad()
        
        pred = model(X)
        loss = criterion(pred, y)
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_accuracy += (torch.argmax(pred, 1) == y).sum()
        
    train_accuracy = train_accuracy.item() / dataset.train_size
        
        
    model.eval()
    val_loss = 0
    val_accuracy = 0
    
    with torch.no_grad():
        for X, y, label in dataset.val_loader:
            X = X.to(device); y = y.to(device)

            pred = model(X)
            loss = criterion(pred, y)

            val_loss += loss.item()
            val_accuracy += (torch.argmax(pred, 1) == y).sum()
        
    val_accuracy = val_accuracy.item() / dataset.val_size
    
    print('Epoch %.2d: train_loss = %.3f, train_accuracy = %.3f, val_loss = %.3f, val_accuracy = %.3f' % (
        epoch, train_loss, train_accuracy, val_loss, val_accuracy
    ))
# Out:
# Epoch 01: train_loss = 1798.179, train_accuracy = 0.486, val_loss = 346.392, val_accuracy = 0.609
# Epoch 02: train_loss = 1272.278, train_accuracy = 0.651, val_loss = 257.747, val_accuracy = 0.711
# Epoch 03: train_loss = 1060.212, train_accuracy = 0.714, val_loss = 223.918, val_accuracy = 0.748
# Epoch 04: train_loss = 906.066, train_accuracy = 0.759, val_loss = 207.283, val_accuracy = 0.774
# Epoch 05: train_loss = 789.055, train_accuracy = 0.789, val_loss = 190.934, val_accuracy = 0.787
# Epoch 06: train_loss = 692.603, train_accuracy = 0.816, val_loss = 188.157, val_accuracy = 0.801
# Epoch 07: train_loss = 605.175, train_accuracy = 0.840, val_loss = 175.501, val_accuracy = 0.811
# Epoch 08: train_loss = 521.653, train_accuracy = 0.863, val_loss = 181.060, val_accuracy = 0.810
# Epoch 09: train_loss = 446.894, train_accuracy = 0.882, val_loss = 162.419, val_accuracy = 0.830
# Epoch 10: train_loss = 392.699, train_accuracy = 0.896, val_loss = 192.046, val_accuracy = 0.808
# Epoch 11: train_loss = 345.768, train_accuracy = 0.909, val_loss = 175.742, val_accuracy = 0.826
# Epoch 12: train_loss = 311.311, train_accuracy = 0.916, val_loss = 186.845, val_accuracy = 0.817
# Epoch 13: train_loss = 269.103, train_accuracy = 0.928, val_loss = 194.732, val_accuracy = 0.821
# Epoch 14: train_loss = 242.218, train_accuracy = 0.935, val_loss = 200.649, val_accuracy = 0.818
# Epoch 15: train_loss = 222.669, train_accuracy = 0.940, val_loss = 201.708, val_accuracy = 0.823
# Epoch 16: train_loss = 201.438, train_accuracy = 0.947, val_loss = 212.794, val_accuracy = 0.818
# Epoch 17: train_loss = 177.362, train_accuracy = 0.953, val_loss = 218.272, val_accuracy = 0.820
# Epoch 18: train_loss = 177.070, train_accuracy = 0.954, val_loss = 223.171, val_accuracy = 0.818
# Epoch 19: train_loss = 159.518, train_accuracy = 0.957, val_loss = 235.888, val_accuracy = 0.818
# Epoch 20: train_loss = 144.034, train_accuracy = 0.961, val_loss = 227.348, val_accuracy = 0.821
# Epoch 21: train_loss = 141.592, train_accuracy = 0.963, val_loss = 230.953, val_accuracy = 0.819
# Epoch 22: train_loss = 143.938, train_accuracy = 0.963, val_loss = 216.784, val_accuracy = 0.829
# Epoch 23: train_loss = 129.619, train_accuracy = 0.966, val_loss = 235.968, val_accuracy = 0.822
# Epoch 24: train_loss = 127.346, train_accuracy = 0.967, val_loss = 241.117, val_accuracy = 0.815
# Epoch 25: train_loss = 120.228, train_accuracy = 0.968, val_loss = 254.817, val_accuracy = 0.816
# Epoch 26: train_loss = 113.112, train_accuracy = 0.970, val_loss = 251.873, val_accuracy = 0.815
# Epoch 27: train_loss = 107.513, train_accuracy = 0.971, val_loss = 258.816, val_accuracy = 0.814
# Epoch 28: train_loss = 106.140, train_accuracy = 0.973, val_loss = 249.732, val_accuracy = 0.819
# Epoch 29: train_loss = 103.904, train_accuracy = 0.974, val_loss = 265.357, val_accuracy = 0.820
# Epoch 30: train_loss = 102.387, train_accuracy = 0.974, val_loss = 252.582, val_accuracy = 0.821
# Epoch 31: train_loss = 93.418, train_accuracy = 0.976, val_loss = 265.222, val_accuracy = 0.818
# Epoch 32: train_loss = 91.096, train_accuracy = 0.976, val_loss = 258.026, val_accuracy = 0.817
# Epoch 33: train_loss = 91.118, train_accuracy = 0.977, val_loss = 262.505, val_accuracy = 0.814
# Epoch 34: train_loss = 83.162, train_accuracy = 0.979, val_loss = 268.948, val_accuracy = 0.817
# Epoch 35: train_loss = 90.018, train_accuracy = 0.977, val_loss = 260.482, val_accuracy = 0.817
# Epoch 36: train_loss = 83.771, train_accuracy = 0.978, val_loss = 258.393, val_accuracy = 0.824
# Epoch 37: train_loss = 81.206, train_accuracy = 0.979, val_loss = 265.699, val_accuracy = 0.821
# Epoch 38: train_loss = 83.351, train_accuracy = 0.979, val_loss = 250.801, val_accuracy = 0.826
# Epoch 39: train_loss = 79.889, train_accuracy = 0.979, val_loss = 249.911, val_accuracy = 0.829
# Epoch 40: train_loss = 74.195, train_accuracy = 0.982, val_loss = 258.939, val_accuracy = 0.828
# Epoch 41: train_loss = 70.594, train_accuracy = 0.981, val_loss = 270.757, val_accuracy = 0.820
# Epoch 42: train_loss = 78.060, train_accuracy = 0.980, val_loss = 262.365, val_accuracy = 0.817
# Epoch 43: train_loss = 66.627, train_accuracy = 0.983, val_loss = 264.679, val_accuracy = 0.826
# Epoch 44: train_loss = 73.479, train_accuracy = 0.981, val_loss = 276.697, val_accuracy = 0.819
# Epoch 45: train_loss = 69.115, train_accuracy = 0.983, val_loss = 271.377, val_accuracy = 0.820
# Epoch 46: train_loss = 64.584, train_accuracy = 0.983, val_loss = 287.322, val_accuracy = 0.820
# Epoch 47: train_loss = 66.550, train_accuracy = 0.983, val_loss = 274.111, val_accuracy = 0.827
# Epoch 48: train_loss = 59.968, train_accuracy = 0.985, val_loss = 288.473, val_accuracy = 0.818
# Epoch 49: train_loss = 66.546, train_accuracy = 0.983, val_loss = 284.395, val_accuracy = 0.815
# Epoch 50: train_loss = 59.968, train_accuracy = 0.984, val_loss = 270.257, val_accuracy = 0.818
# Epoch 51: train_loss = 64.715, train_accuracy = 0.983, val_loss = 285.074, val_accuracy = 0.814
# Epoch 52: train_loss = 60.814, train_accuracy = 0.985, val_loss = 274.845, val_accuracy = 0.824
# Epoch 53: train_loss = 62.814, train_accuracy = 0.984, val_loss = 270.096, val_accuracy = 0.822
# Epoch 54: train_loss = 59.570, train_accuracy = 0.985, val_loss = 273.562, val_accuracy = 0.825
# Epoch 55: train_loss = 57.696, train_accuracy = 0.985, val_loss = 295.788, val_accuracy = 0.812
# Epoch 56: train_loss = 55.391, train_accuracy = 0.986, val_loss = 283.529, val_accuracy = 0.824
# Epoch 57: train_loss = 58.599, train_accuracy = 0.985, val_loss = 293.067, val_accuracy = 0.818
# Epoch 58: train_loss = 49.935, train_accuracy = 0.987, val_loss = 296.567, val_accuracy = 0.822
# Epoch 59: train_loss = 51.909, train_accuracy = 0.986, val_loss = 296.052, val_accuracy = 0.825
# Epoch 60: train_loss = 55.909, train_accuracy = 0.986, val_loss = 283.570, val_accuracy = 0.821
# Epoch 61: train_loss = 54.142, train_accuracy = 0.986, val_loss = 293.172, val_accuracy = 0.820
# Epoch 62: train_loss = 50.378, train_accuracy = 0.987, val_loss = 300.114, val_accuracy = 0.815
# Epoch 63: train_loss = 55.139, train_accuracy = 0.986, val_loss = 276.607, val_accuracy = 0.826
# Epoch 64: train_loss = 51.845, train_accuracy = 0.987, val_loss = 283.903, val_accuracy = 0.825
# Epoch 65: train_loss = 49.418, train_accuracy = 0.987, val_loss = 290.119, val_accuracy = 0.823
# Epoch 66: train_loss = 45.336, train_accuracy = 0.988, val_loss = 282.158, val_accuracy = 0.822
# Epoch 67: train_loss = 44.886, train_accuracy = 0.988, val_loss = 313.271, val_accuracy = 0.817
# Epoch 68: train_loss = 49.957, train_accuracy = 0.988, val_loss = 291.226, val_accuracy = 0.822
# Epoch 69: train_loss = 44.369, train_accuracy = 0.989, val_loss = 307.854, val_accuracy = 0.824
# Epoch 70: train_loss = 49.302, train_accuracy = 0.988, val_loss = 289.220, val_accuracy = 0.826
# Epoch 71: train_loss = 46.461, train_accuracy = 0.987, val_loss = 309.341, val_accuracy = 0.818
# Epoch 72: train_loss = 42.373, train_accuracy = 0.989, val_loss = 321.781, val_accuracy = 0.812
# Epoch 73: train_loss = 49.017, train_accuracy = 0.988, val_loss = 307.902, val_accuracy = 0.820
# Epoch 74: train_loss = 41.985, train_accuracy = 0.989, val_loss = 315.426, val_accuracy = 0.819
# Epoch 75: train_loss = 42.820, train_accuracy = 0.990, val_loss = 308.674, val_accuracy = 0.820
# Epoch 76: train_loss = 40.031, train_accuracy = 0.990, val_loss = 308.300, val_accuracy = 0.817
# Epoch 77: train_loss = 44.978, train_accuracy = 0.989, val_loss = 321.585, val_accuracy = 0.818
# Epoch 78: train_loss = 47.822, train_accuracy = 0.988, val_loss = 302.164, val_accuracy = 0.822
# Epoch 79: train_loss = 41.198, train_accuracy = 0.989, val_loss = 303.631, val_accuracy = 0.821
# Epoch 80: train_loss = 40.438, train_accuracy = 0.990, val_loss = 310.972, val_accuracy = 0.819
# Epoch 81: train_loss = 43.394, train_accuracy = 0.989, val_loss = 322.503, val_accuracy = 0.812
# Epoch 82: train_loss = 37.806, train_accuracy = 0.991, val_loss = 326.302, val_accuracy = 0.814
# Epoch 83: train_loss = 40.593, train_accuracy = 0.990, val_loss = 322.986, val_accuracy = 0.817
# Epoch 84: train_loss = 37.236, train_accuracy = 0.990, val_loss = 317.865, val_accuracy = 0.823
# Epoch 85: train_loss = 41.929, train_accuracy = 0.990, val_loss = 309.856, val_accuracy = 0.824
# Epoch 86: train_loss = 38.346, train_accuracy = 0.990, val_loss = 300.958, val_accuracy = 0.827
# Epoch 87: train_loss = 37.926, train_accuracy = 0.990, val_loss = 303.059, val_accuracy = 0.821
# Epoch 88: train_loss = 43.105, train_accuracy = 0.989, val_loss = 313.564, val_accuracy = 0.817
# Epoch 89: train_loss = 32.538, train_accuracy = 0.991, val_loss = 331.268, val_accuracy = 0.816
# Epoch 90: train_loss = 37.427, train_accuracy = 0.991, val_loss = 332.148, val_accuracy = 0.815
# Epoch 91: train_loss = 41.260, train_accuracy = 0.989, val_loss = 319.325, val_accuracy = 0.817
# Epoch 92: train_loss = 36.647, train_accuracy = 0.991, val_loss = 323.648, val_accuracy = 0.816
# Epoch 93: train_loss = 30.290, train_accuracy = 0.992, val_loss = 334.919, val_accuracy = 0.821
# Epoch 94: train_loss = 39.571, train_accuracy = 0.990, val_loss = 333.779, val_accuracy = 0.818
# Epoch 95: train_loss = 36.334, train_accuracy = 0.991, val_loss = 317.946, val_accuracy = 0.819
# Epoch 96: train_loss = 35.873, train_accuracy = 0.991, val_loss = 327.999, val_accuracy = 0.821
# Epoch 97: train_loss = 32.936, train_accuracy = 0.992, val_loss = 328.471, val_accuracy = 0.817
# Epoch 98: train_loss = 35.858, train_accuracy = 0.991, val_loss = 348.675, val_accuracy = 0.814
# Epoch 99: train_loss = 36.365, train_accuracy = 0.991, val_loss = 327.540, val_accuracy = 0.820
# Epoch 100: train_loss = 35.444, train_accuracy = 0.991, val_loss = 320.960, val_accuracy = 0.819

# %%
model_filename = os.path.join('models', 'cifar10.pt')
torch.save(model.state_dict(), model_filename)

# %%
model.eval()
test_accuracy = 0

with torch.no_grad():
    for X, y, label in dataset.test_loader:
        X = X.to(device); y = y.to(device)

        pred = model(X)
        test_accuracy += (torch.argmax(pred, 1) == y).sum()

test_accuracy = test_accuracy.item() / dataset.test_size

print('Test accuracy: %.3f' % test_accuracy)
print('Test error rate: %.3f' % (1 - test_accuracy))
# Out:
# Test accuracy: 0.823
# Test error rate: 0.177
