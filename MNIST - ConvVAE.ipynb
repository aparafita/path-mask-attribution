# %%
import os.path

import torch
from torch import nn, optim

import numpy as np

% matplotlib inline
import matplotlib.pyplot as plt

from mnist_cnn import *
from utils import *

# %%
DISABLE_CUDA = False

if not DISABLE_CUDA and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
dataset = MNIST(
    os.path.join(*'data/MNIST'.split('/')),
    batch_size=32, val_size=.2
)

# %%
model = load_model(mnist_model(), os.path.join('models', 'mnist.pt'), device)

model.eval()
test_accuracy = 0

with torch.no_grad():
    for X, y, label in dataset.test_loader:
        X = X.to(device); y = y.to(device)

        pred = model(X)
        test_accuracy += (torch.argmax(pred, 1) == y).sum()

test_accuracy = test_accuracy.item() / dataset.test_size

print('Test accuracy: %.3f' % test_accuracy)
print('Test error rate: %.3f' % (1 - test_accuracy))
# Out:
# Test accuracy: 0.993
# Test error rate: 0.007

# %%
emb_dim = 100
N_EPOCHS = 100

vae = ConvVAE(emb_dim).to(device)
model_path = os.path.join('models', 'conv_vae_mnist.pt')

optimizer = optim.Adam(vae.parameters())

train_losses = []
val_losses = []

# Train model
for epoch in range(1, N_EPOCHS + 1):
    vae.train()
    
    train_loss = 0
    
    for X, _, _ in dataset.train_loader:
        X = X.to(device)
        
        optimizer.zero_grad()
        recon_X, mu, logvar, code = vae(X)
        
        loss = vae.loss(recon_X, X, mu, logvar)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
    train_loss /= dataset.train_size
    train_losses.append(train_loss)
    
    
    vae.eval()
    
    val_loss = 0
    
    with torch.no_grad():
        for X, _, _ in dataset.val_loader:
            X = X.to(device)

            optimizer.zero_grad()
            recon_X, mu, logvar, code = vae(X)
            loss = vae.loss(recon_X, X, mu, logvar)

            val_loss += loss.item()
        
    val_loss /= dataset.val_size
    val_losses.append(val_loss)
    
    print('Epoch %.3d: train_loss = %.3f, val_loss = %.3f' % (
        epoch, train_loss, val_loss
    ))
    

plt.plot(torch.Tensor(train_losses).cpu().detach().numpy(), label='train_loss')
plt.plot(torch.Tensor(val_losses).cpu().detach().numpy(), label='val_loss')
plt.legend();

torch.save(vae.state_dict(), model_path)
# Out:
# Epoch 001: train_loss = 336.265, val_loss = 208.380
# Epoch 002: train_loss = 205.609, val_loss = 153.654
# Epoch 003: train_loss = 166.931, val_loss = 133.367
# Epoch 004: train_loss = 152.216, val_loss = 123.469
# Epoch 005: train_loss = 145.996, val_loss = 120.666
# Epoch 006: train_loss = 142.953, val_loss = 117.653
# Epoch 007: train_loss = 141.085, val_loss = 115.659
# Epoch 008: train_loss = 139.920, val_loss = 114.543
# Epoch 009: train_loss = 138.926, val_loss = 114.610
# Epoch 010: train_loss = 138.530, val_loss = 112.871
# Epoch 011: train_loss = 138.017, val_loss = 112.639
# Epoch 012: train_loss = 137.733, val_loss = 111.876
# Epoch 013: train_loss = 136.995, val_loss = 112.298
# Epoch 014: train_loss = 136.846, val_loss = 111.174
# Epoch 015: train_loss = 136.602, val_loss = 111.840
# Epoch 016: train_loss = 136.313, val_loss = 111.834
# Epoch 017: train_loss = 136.065, val_loss = 111.073
# Epoch 018: train_loss = 135.720, val_loss = 110.451
# Epoch 019: train_loss = 135.573, val_loss = 110.540
# Epoch 020: train_loss = 135.460, val_loss = 110.326
# Epoch 021: train_loss = 135.402, val_loss = 110.299
# Epoch 022: train_loss = 135.140, val_loss = 109.889
# Epoch 023: train_loss = 134.981, val_loss = 109.901
# Epoch 024: train_loss = 134.713, val_loss = 110.069
# Epoch 025: train_loss = 134.604, val_loss = 109.625
# Epoch 026: train_loss = 134.562, val_loss = 109.410
# Epoch 027: train_loss = 134.382, val_loss = 109.603
# Epoch 028: train_loss = 134.251, val_loss = 109.612
# Epoch 029: train_loss = 134.277, val_loss = 108.905
# Epoch 030: train_loss = 133.925, val_loss = 109.984
# Epoch 031: train_loss = 134.023, val_loss = 108.410
# Epoch 032: train_loss = 133.952, val_loss = 109.444
# Epoch 033: train_loss = 133.725, val_loss = 109.312
# Epoch 034: train_loss = 133.665, val_loss = 108.414
# Epoch 035: train_loss = 133.580, val_loss = 108.707
# Epoch 036: train_loss = 133.587, val_loss = 108.840
# Epoch 037: train_loss = 133.285, val_loss = 108.149
# Epoch 038: train_loss = 133.344, val_loss = 108.650
# Epoch 039: train_loss = 133.376, val_loss = 108.222
# Epoch 040: train_loss = 133.364, val_loss = 109.144
# Epoch 041: train_loss = 133.202, val_loss = 108.684
# Epoch 042: train_loss = 133.202, val_loss = 108.503
# Epoch 043: train_loss = 133.285, val_loss = 108.445
# Epoch 044: train_loss = 133.211, val_loss = 108.117
# Epoch 045: train_loss = 133.048, val_loss = 108.311
# Epoch 046: train_loss = 132.928, val_loss = 108.074
# Epoch 047: train_loss = 132.985, val_loss = 108.581
# Epoch 048: train_loss = 132.805, val_loss = 108.008
# Epoch 049: train_loss = 132.894, val_loss = 108.192
# Epoch 050: train_loss = 132.896, val_loss = 108.049
# Epoch 051: train_loss = 132.804, val_loss = 108.293
# Epoch 052: train_loss = 132.853, val_loss = 108.155
# Epoch 053: train_loss = 132.618, val_loss = 108.412
# Epoch 054: train_loss = 132.682, val_loss = 108.422
# Epoch 055: train_loss = 132.540, val_loss = 108.426
# Epoch 056: train_loss = 132.604, val_loss = 107.726
# Epoch 057: train_loss = 132.525, val_loss = 108.382
# Epoch 058: train_loss = 132.567, val_loss = 108.128
# Epoch 059: train_loss = 132.500, val_loss = 107.912
# Epoch 060: train_loss = 132.466, val_loss = 107.492
# Epoch 061: train_loss = 132.341, val_loss = 107.595
# Epoch 062: train_loss = 132.355, val_loss = 107.836
# Epoch 063: train_loss = 132.438, val_loss = 107.774
# Epoch 064: train_loss = 132.251, val_loss = 107.834
# Epoch 065: train_loss = 132.332, val_loss = 107.298
# Epoch 066: train_loss = 132.305, val_loss = 107.652
# Epoch 067: train_loss = 132.243, val_loss = 107.436
# Epoch 068: train_loss = 132.213, val_loss = 108.055
# Epoch 069: train_loss = 132.195, val_loss = 107.878
# Epoch 070: train_loss = 132.178, val_loss = 107.439
# Epoch 071: train_loss = 132.177, val_loss = 107.679
# Epoch 072: train_loss = 132.051, val_loss = 107.425
# Epoch 073: train_loss = 132.010, val_loss = 107.110
# Epoch 074: train_loss = 132.033, val_loss = 107.635
# Epoch 075: train_loss = 131.992, val_loss = 107.497
# Epoch 076: train_loss = 131.989, val_loss = 107.090
# Epoch 077: train_loss = 131.965, val_loss = 107.734
# Epoch 078: train_loss = 131.963, val_loss = 107.262
# Epoch 079: train_loss = 131.891, val_loss = 107.107
# Epoch 080: train_loss = 131.869, val_loss = 107.211
# Epoch 081: train_loss = 131.950, val_loss = 107.334
# Epoch 082: train_loss = 131.768, val_loss = 107.586
# Epoch 083: train_loss = 131.731, val_loss = 107.665
# Epoch 084: train_loss = 131.897, val_loss = 107.133
# Epoch 085: train_loss = 131.832, val_loss = 107.235
# Epoch 086: train_loss = 131.811, val_loss = 107.492
# Epoch 087: train_loss = 131.726, val_loss = 107.139
# Epoch 088: train_loss = 131.762, val_loss = 107.004
# Epoch 089: train_loss = 131.720, val_loss = 107.458
# Epoch 090: train_loss = 131.683, val_loss = 106.986
# Epoch 091: train_loss = 131.722, val_loss = 107.300
# Epoch 092: train_loss = 131.601, val_loss = 106.844
# Epoch 093: train_loss = 131.817, val_loss = 107.043
# Epoch 094: train_loss = 131.731, val_loss = 107.606
# Epoch 095: train_loss = 131.670, val_loss = 107.525
# Epoch 096: train_loss = 131.558, val_loss = 107.426
# Epoch 097: train_loss = 131.538, val_loss = 107.304
# Epoch 098: train_loss = 131.670, val_loss = 107.303
# Epoch 099: train_loss = 131.512, val_loss = 106.907
# Epoch 100: train_loss = 131.601, val_loss = 106.956

# %%
emb_dim = 100

vae = ConvVAE(emb_dim).to(device)
model_path = os.path.join('models', 'conv_vae_mnist.pt')
vae.load_state_dict(torch.load(model_path))

vae = vae.eval()

# %%
axes = subplots(10, 10, plot_size=1).flatten()

code = torch.randn(len(axes), emb_dim).to(device)
decoded = vae.decode(code)

for ax, img in zip(axes, decoded):
    imshow(img[0].detach(), ax)

# %%
axes_mat = subplots(10, 10).reshape(50, 2)

idxs = np.random.choice(dataset.test_size, len(axes_mat), replace=False)

for axes, idx in zip(axes_mat, idxs):
    test_idx = dataset.test[idx]
    img, y, label = dataset[test_idx]
    img = img.to(device).unsqueeze(0)
    rec_img = vae(img)[0][0, 0].detach()
    
    imshow(img[0, 0].detach(), axes[0])
    axes[0].set_title('%d (%s)' % (idx, label))
    imshow(rec_img, axes[1])

# %% [markdown]
# We'll use the embedding norm as a measure of the likelihood of a code belonging to the manifold.
#
# Let's analyze then the norm distribution:

# %%
codes = []
ys = []

for X, y, _ in dataset.train_loader:
    X = X.to(device)
    
    code, _ = vae.encode(X)
    codes.append(code.detach()); ys.append(y)
    
codes = torch.cat(codes)
ys = torch.cat(ys)
ys = ys.cpu().detach().numpy().astype(int)

# %%
norms = codes.norm(p=2, dim=1).cpu().detach().numpy()
plt.hist(norms);

# %%
axes = subplots(2, 5, sharex=True).flatten()
class_means = {}

for y, ax in enumerate(axes):
    subset = norms[ys == y]
    norm_mean = subset.mean()
    class_means[int(y)] = float(norm_mean)
    
    ax.hist(subset)
    ax.axvline(norm_mean, linestyle='dashed', color='red')
    ax.set_title('Emb. norm for %s (mean %.2f)' % (dataset.classes[y], norm_mean))
    
class_means[-1] = float(norms.mean())

# %% [markdown]
# This is clearly not a normal distribution, even if we split by class. In any case, we'll still work by that assumption for the sake of simplicity.

# %%
class_means
# Out:
# {-1: 3.035032272338867,
#  0: 3.311706066131592,
#  1: 2.793889045715332,
#  2: 3.243734359741211,
#  3: 2.9805784225463867,
#  4: 3.1270899772644043,
#  5: 3.0062901973724365,
#  6: 3.2144525051116943,
#  7: 3.094365119934082,
#  8: 2.849363327026367,
#  9: 2.7558236122131348}

# %%
import json

with open('data/mnist_conv_vae_norm_means.json', 'w') as f:
    json.dump(class_means, f)
